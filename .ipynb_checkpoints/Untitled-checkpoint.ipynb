# %%
from itertools import chain,combinations
def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

# %%
W = WeylGroup("A3", prefix = "s")
s = W.simple_reflections()
torsA = W.weak_poset()
c_Q = W.from_reduced_word([1,2,3])
torsA = torsA.subposet([w for w in W if w.is_coxeter_sortable(c_Q)])

# %%
torsA = LatticePoset(torsA, facade = True)
modA = torsA.top()
tors0 = torsA.bottom()

# %%
ice_int = [(modA,modA)] # the list of sincere ICE intervals. We must add 0.
for U in torsA:
    if U == modA:
        continue
    U_upper = torsA.upper_covers(U)
    U_plus = torsA.join(U_upper)
    inter_tors = set(torsA.closed_interval(U,U_plus)) - {U}
    for arrow_set in powerset(U_upper):
        if len(arrow_set) == 0 or len(arrow_set) == len(U_upper):
            continue
        T = torsA.join(arrow_set)
        inter_tors = inter_tors - set(torsA.closed_interval(U,T))
    ice_int = ice_int + ([(U,T) for T in inter_tors])

print (f"There are {len(ice_int)} ICEs!")
# Out:
# There are 22 ICEs!

# %%
# We will compute join-irreducible labeling!
label = dict()

# For covering relation U < V, its join-irred labeling is
# the unique smallest element T satisfying U \vee T = V.
for U,V in torsA.cover_relations_iterator():
    tmp_poset = torsA.subposet([T for T in torsA if torsA.join(U,T) == V])
    label[(U,V)] = tmp_poset.bottom()

# %%
def brick_seq(L): # return the set of brick seq ass. to chain (list) L of torsion classes
    seq = set()
    for U,T in zip(L,L[1:]):
        seq.add(label[(U,T)])
    return seq

# %%
# return the frozen set of bricks in intervals I = [U,T]
def allbricks(I):
    U,T = I
    setofbrick = set()
    interval_poset = torsA.subposet(torsA.closed_interval(U,T))
    for seq in interval_poset.maximal_chains():
        setofbrick = setofbrick | brick_seq(seq)
    return setofbrick

# %%
def geq_ice_int(I, J):
    return allbricks(I).issubset(allbricks(J))

# %%
ice_poset = Poset((ice_int,geq_ice_int))
ice_poset
# Out:
# Finite poset containing 22 elements (use the .plot() method to plot)

# %%
b
# Out:
# Graphics object consisting of 42 graphics primitives

# %%
P = posets.Crown(3)

# %%
P
# Out:
# Finite poset containing 6 elements

# %%
LatticePoset(P)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-e7a20ca7c93c> in <module>()
# ----> 1 LatticePoset(P)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/combinat/posets/lattices.py in LatticePoset(data, *args, **options)
#     755     if P.cardinality() != 0:
#     756         if not P.has_bottom():
# --> 757             raise ValueError("not a meet-semilattice: no bottom element")
#     758         try:
#     759             P._hasse_diagram.join_matrix()
#
# ValueError: not a meet-semilattice: no bottom element

# %%
lattice = torsA

# %%
j_irr = lattice.join_irreducibles()
m_irr = lattice.meet_irreducibles()

# %%
for j in j_irr:
    print (f"Consider join-irred. {j}")
    j_star = lattice.lower_covers(j)[0]
    print (f"Its below one is {j_star}")
# Out:
# Consider join-irred. s3
# Its below one is 1
# Consider join-irred. s2
# Its below one is 1
# Consider join-irred. s2*s3
# Its below one is s2
# Consider join-irred. s1
# Its below one is 1
# Consider join-irred. s1*s2
# Its below one is s1
# Consider join-irred. s1*s2*s3
# Its below one is s1*s2

# %% [raw]
# next(torsA.upper_covers_iterator(tors0))
