# %%
1+1
# Out:
# 2

# %%
load ("kappa.py")

# %%
L = posets.PentagonPoset()
L
# Out:
# Finite lattice containing 5 elements

# %%
for x in L:
    print(f"{x} goes to {L.extended_kappa(x)}")
# Out:
# 0 goes to 4
# 1 goes to 3
# 2 goes to 1
# 3 goes to 2
# 4 goes to 0

# %%
for x in L:
    print(f"{x} goes to {L.extended_kappa_dual(x)}")
# Out:
# 0 goes to 4
# 1 goes to 2
# 2 goes to 3
# 3 goes to 1
# 4 goes to 0

# %%
for x in L:
    y = L.extended_kappa(x)
    xx = L.extended_kappa_dual(y)
    print (f"{x} -kappa-> {y} -kappa_dual-> {xx}")
# Out:
# 0 -kappa-> 4 -kappa_dual-> 0
# 1 -kappa-> 3 -kappa_dual-> 1
# 2 -kappa-> 1 -kappa_dual-> 2
# 3 -kappa-> 2 -kappa_dual-> 3
# 4 -kappa-> 0 -kappa_dual-> 4

# %%
W = WeylGroup("A3", prefix = "s")
s = W.simple_reflections()

# %%
W_lat = W.weak_lattice()

# %%
for x in W_lat:
    y = W_lat.extended_kappa(x)
    xx = W_lat.extended_kappa_dual(y)
    print (f"{x} -kappa-> {y} -kappa_dual-> {xx}")
# Out:
# 1 -kappa-> s1*s2*s3*s1*s2*s1 -kappa_dual-> 1
# s3 -kappa-> s1*s2*s3*s1*s2 -kappa_dual-> s3
# s2 -kappa-> s1*s2*s3*s2*s1 -kappa_dual-> s2
# s3*s2 -kappa-> s1*s2*s3*s2 -kappa_dual-> s3*s2
# s2*s3 -kappa-> s1*s2*s3*s1 -kappa_dual-> s2*s3
# s2*s3*s2 -kappa-> s1*s2*s3 -kappa_dual-> s2*s3*s2
# s1 -kappa-> s2*s3*s1*s2*s1 -kappa_dual-> s1
# s3*s1 -kappa-> s2*s3*s1*s2 -kappa_dual-> s3*s1
# s2*s1 -kappa-> s2*s3*s2*s1 -kappa_dual-> s2*s1
# s3*s2*s1 -kappa-> s2*s3*s2 -kappa_dual-> s3*s2*s1
# s2*s3*s1 -kappa-> s2 -kappa_dual-> s2*s3*s1
# s2*s3*s2*s1 -kappa-> s3*s2 -kappa_dual-> s2*s3*s2*s1
# s1*s2 -kappa-> s3*s1*s2*s1 -kappa_dual-> s1*s2
# s3*s1*s2 -kappa-> s3*s1 -kappa_dual-> s3*s1*s2
# s1*s2*s1 -kappa-> s3*s2*s1 -kappa_dual-> s1*s2*s1
# s3*s1*s2*s1 -kappa-> s3 -kappa_dual-> s3*s1*s2*s1
# s2*s3*s1*s2 -kappa-> s2*s3*s1 -kappa_dual-> s2*s3*s1*s2
# s2*s3*s1*s2*s1 -kappa-> s2*s3 -kappa_dual-> s2*s3*s1*s2*s1
# s1*s2*s3 -kappa-> s1*s2*s1 -kappa_dual-> s1*s2*s3
# ...

# %%
L = LatticePoset({1: [2, 3], 2: [4, 5], 3: [6], 4: [6], 5: [6]})

# %%
for x in L:
    print(f"{x} goes to {extended_kappa(L,x)}")
# Out:
# 1 goes to 6
# 2 goes to 3
# 4 goes to 5
# 5 goes to 4
# 3 goes to None
# 6 goes to None

# %%
L
# Out:
# Finite lattice containing 6 elements
