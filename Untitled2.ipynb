# %%
W = WeylGroup("A5", prefix = "s")
s = W.simple_reflections()
c_Q = W.from_reduced_word([2,1,3,5,4])

# %%
# %%time
els = [x for x in W if x.absolute_le(c_Q)]
NC1 = Poset((els, attrcall("absolute_le")))
# Out:
# CPU times: user 719 ms, sys: 0 ns, total: 719 ms
# Wall time: 716 ms

# %%
NC1
# Out:
# Finite poset containing 14 elements

# %%
load("tors_lattice.py")

# %%
poset = W.cambrian_lattice((2,1,3,5,4))
tors = TorsLattice(poset)

# %%
# %time NC = tors.wide_lattice()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-3fcc8f69e797> in <module>()
# ----> 1 get_ipython().magic('timeit NC = tors.wide_lattice()')
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# ...

# %%
NC.is_isomorphic(NC2)
# Out:
# True

# %%
# %time NC_new = tors.wide_lattice2()
# Out:
# CPU times: user 1min 42s, sys: 0 ns, total: 1min 42s
# Wall time: 1min 42s

# %%
# %time NC_newnew = tors.wide_lattice2()
# Out:
# CPU times: user 45.1 s, sys: 0 ns, total: 45.1 s
# Wall time: 45.1 s

# %%
NC_new.is_isomorphic(NC_newnew)
# Out:
# True

# %%
tors_pi = TorsLattice(W.weak_lattice())

# %%
wide_pi = tors_pi.wide_lattice2()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-ee74672d116c> in <module>()
# ----> 1 wide_pi = tors_pi.wide_lattice2()
#
# /home/sage/Documents/GitHub/ice-from-tors/tors_lattice.py in wide_lattice2(self)
#      75     def wide_lattice2(self):
#      76         wide_itvs = [(self.minus(T), T) for T in self]
# ---> 77         return LatticePoset((wide_itvs, self.wide_lequal))
#      78
#      79
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/combinat/posets/lattices.py in LatticePoset(data, *args, **options)
#     752     if isinstance(data, FiniteLatticePoset) and not args and not options:
#     753         return data
# --> 754     P = Poset(data, *args, **options)
#     755     if P.cardinality() != 0:
#     756         if not P.has_bottom():
#
# ...
